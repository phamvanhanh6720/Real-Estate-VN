# %%
import os
from datetime import datetime

import matplotlib.pyplot as plt

# %%
from utils import parser_log, create_visualize_figure

# %%
counting_reports, total_time = parser_log('logs/batdongsan_2023-01-11.log')

# %%
create_visualize_figure(counting_reports, save_file='daily_reports/batdongsan_2023-01-11.png')
